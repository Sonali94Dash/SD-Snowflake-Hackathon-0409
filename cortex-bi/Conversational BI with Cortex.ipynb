# %%
%%sql -r dataframe_5
-- Step 1: Create schema and stage for Cortex Analyst
CREATE SCHEMA IF NOT EXISTS HACKATHON_DB.CORTEX_BI;
USE SCHEMA HACKATHON_DB.CORTEX_BI;

CREATE OR REPLACE STAGE HACKATHON_DB.CORTEX_BI.SEMANTIC_MODELS
  DIRECTORY = (ENABLE = TRUE);

# %%
%%sql -r dataframe_1
-- Just verify the stage exists
LIST @HACKATHON_DB.CORTEX_BI.SEMANTIC_MODELS;

# %%
%%sql -r dataframe_2
SELECT DISTINCT VARIABLE_NAME 
FROM SNOWFLAKE_PUBLIC_DATA_FREE.PUBLIC_DATA_FREE.FINANCIAL_ECONOMIC_INDICATORS_TIMESERIES 
WHERE VARIABLE_NAME ILIKE '%money%' 
LIMIT 10;
